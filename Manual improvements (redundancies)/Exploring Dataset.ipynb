# %%
import pandas as pd
from collections import Counter
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#reading each individual CAR file
jan1_jan18_2025 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (01-12-25 - 01-18-25).xlsx')
jan1_jan18_2025.columns = jan1_jan18_2025.loc[1,:]
jan1_jan18_2025=jan1_jan18_2025.drop(index=[0,1]).reset_index()
jan1_jan18_2025.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
jan19_feb1_2025 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (01-19-25 - 02-01-25).xlsx')
jan19_feb1_2025.columns = jan19_feb1_2025.loc[1,:]
jan19_feb1_2025=jan19_feb1_2025.drop(index=[0,1]).reset_index()
jan19_feb1_2025.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
feb2_feb15_2025 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (02-02-25 - 02-15-25).xlsx')
feb2_feb15_2025.columns = feb2_feb15_2025.loc[1,:]
feb2_feb15_2025=feb2_feb15_2025.drop(index=[0,1]).reset_index()
feb2_feb15_2025.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
feb16_mar1_2025 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (02-16-25 - 03-01-25).xlsx')
feb16_mar1_2025.columns = feb16_mar1_2025.loc[1,:]
feb16_mar1_2025=feb16_mar1_2025.drop(index=[0,1]).reset_index()
feb16_mar1_2025.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
mar2_mar15_2025 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (03-02-25 - 03-15-25).xlsx')
mar2_mar15_2025.columns = mar2_mar15_2025.loc[1,:]
mar2_mar15_2025=mar2_mar15_2025.drop(index=[0,1]).reset_index()
mar2_mar15_2025.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
apr7_apr20_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (04-07-24 - 04-20-24).xlsx')
apr7_apr20_2024.columns = apr7_apr20_2024.loc[1,:]
apr7_apr20_2024=apr7_apr20_2024.drop(index=[0,1]).reset_index()
apr7_apr20_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
apr21_may4_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (04-21-24 - 05-04-24).xlsx')
apr21_may4_2024.columns = apr21_may4_2024.loc[1,:]
apr21_may4_2024=apr21_may4_2024.drop(index=[0,1]).reset_index()
apr21_may4_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
may5_may18_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (05-05-24 - 05-18-24).xlsx')
may5_may18_2024.columns = may5_may18_2024.loc[1,:]
may5_may18_2024=may5_may18_2024.drop(index=[0,1]).reset_index()
may5_may18_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
may19_jun1_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (05-19-24 - 06-01-24).xlsx')
may19_jun1_2024.columns = may19_jun1_2024.loc[1,:]
may19_jun1_2024=may19_jun1_2024.drop(index=[0,1]).reset_index()
may19_jun1_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
jun2_jun15_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (06-02-24 - 06-15-24).xlsx')
jun2_jun15_2024.columns = jun2_jun15_2024.loc[1,:]
jun2_jun15_2024=jun2_jun15_2024.drop(index=[0,1]).reset_index()
jun2_jun15_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
jun16_jun29_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (06-16-24 - 06-29-24).xlsx')
jun16_jun29_2024.columns = jun16_jun29_2024.loc[1,:]
jun16_jun29_2024=jun16_jun29_2024.drop(index=[0,1]).reset_index()
jun16_jun29_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
jun30_jul13_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (06-30-24 - 07-13-24).xlsx')
jun30_jul13_2024.columns = jun30_jul13_2024.loc[1,:]
jun30_jul13_2024=jun30_jul13_2024.drop(index=[0,1]).reset_index()
jun30_jul13_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
jul14_jul27_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (07-14-24 - 07-27-24).xlsx')
jul14_jul27_2024.columns = jul14_jul27_2024.loc[1,:]
jul14_jul27_2024=jul14_jul27_2024.drop(index=[0,1]).reset_index()
jul14_jul27_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
jul28_aug10_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (07-28-24 - 08-10-24).xlsx')
jul28_aug10_2024.columns = jul28_aug10_2024.loc[1,:]
jul28_aug10_2024=jul28_aug10_2024.drop(index=[0,1]).reset_index()
jul28_aug10_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
aug11_aug24_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (08-11-24 - 08-24-24).xlsx')
aug11_aug24_2024.columns = aug11_aug24_2024.loc[1,:]
aug11_aug24_2024=aug11_aug24_2024.drop(index=[0,1]).reset_index()
aug11_aug24_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
aug24_sep7_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (08-24-24 - 09-07-24).xlsx')
aug24_sep7_2024.columns = aug24_sep7_2024.loc[1,:]
aug24_sep7_2024=aug24_sep7_2024.drop(index=[0,1]).reset_index()
aug24_sep7_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
sep8_sep21_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (09-08-24 - 09-21-24).xlsx')
sep8_sep21_2024.columns = sep8_sep21_2024.loc[1,:]
sep8_sep21_2024=sep8_sep21_2024.drop(index=[0,1]).reset_index()
sep8_sep21_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
sep22_oct5_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (09-22-24 - 10-05-24).xlsx')
sep22_oct5_2024.columns = sep22_oct5_2024.loc[1,:]
sep22_oct5_2024=sep22_oct5_2024.drop(index=[0,1]).reset_index()
sep22_oct5_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
oct6_oct19_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (10-06-24 - 10-19-24).xlsx')
oct6_oct19_2024.columns = oct6_oct19_2024.loc[1,:]
oct6_oct19_2024=oct6_oct19_2024.drop(index=[0,1]).reset_index()
oct6_oct19_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
oct20_nov2_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (10-20-24 - 11-02-24).xlsx')
oct20_nov2_2024.columns = oct20_nov2_2024.loc[1,:]
oct20_nov2_2024=oct20_nov2_2024.drop(index=[0,1]).reset_index()
oct20_nov2_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
nov3_nov16_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (11-03-24 - 11-16-24).xlsx')
nov3_nov16_2024.columns = nov3_nov16_2024.loc[1,:]
nov3_nov16_2024=nov3_nov16_2024.drop(index=[0,1]).reset_index()
nov3_nov16_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
nov17_nov30_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (11-17-24 - 11-30-24).xlsx')
nov17_nov30_2024.columns = nov17_nov30_2024.loc[1,:]
nov17_nov30_2024=nov17_nov30_2024.drop(index=[0,1]).reset_index()
nov17_nov30_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
dec1_dec14_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (12-01-24 - 12-14-24).xlsx')
dec1_dec14_2024.columns = dec1_dec14_2024.loc[1,:]
dec1_dec14_2024=dec1_dec14_2024.drop(index=[0,1]).reset_index()
dec1_dec14_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
dec15_dec28_2024 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (12-15-24 - 12-28-24).xlsx')
dec15_dec28_2024.columns = dec15_dec28_2024.loc[1,:]
dec15_dec28_2024=dec15_dec28_2024.drop(index=[0,1]).reset_index()
dec15_dec28_2024.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
dec29_2024_jan11_2025 = pd.read_excel('./Call journey data/CAR - EP, Flow, Activity, Queue, & Agent Names (12-29-24 - 01-11-25).xlsx')
dec29_2024_jan11_2025.columns = dec29_2024_jan11_2025.loc[1,:]
dec29_2024_jan11_2025=dec29_2024_jan11_2025.drop(index=[0,1]).reset_index()
dec29_2024_jan11_2025.drop(columns='index',inplace=True)
# Out:
# /Users/danielgold/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
#combining into one dataset
combined_data = pd.concat([apr7_apr20_2024,apr21_may4_2024,may5_may18_2024,may19_jun1_2024,jun2_jun15_2024,jun16_jun29_2024,jun30_jul13_2024,jul14_jul27_2024,jul28_aug10_2024,aug11_aug24_2024,aug24_sep7_2024,sep8_sep21_2024,sep22_oct5_2024,oct6_oct19_2024,oct20_nov2_2024,nov3_nov16_2024,nov17_nov30_2024,dec1_dec14_2024,dec15_dec28_2024,dec29_2024_jan11_2025,jan1_jan18_2025,jan19_feb1_2025,feb2_feb15_2025,feb16_mar1_2025,mar2_mar15_2025],axis=0)

# %%
#dictionary that stores each type of flow and defaults to zero, this is used for many of the below functions
flow_keys = list(combined_data['Flow Name'].dropna().unique())
flow_keys.append('MainMenu')
flow_keys.append('HolidayClosedMenu')
flow_values = np.zeros(160)
flow_dict= dict(zip(flow_keys, flow_values))

#ditto for activity
act_keys = combined_data['Activity Name'].dropna().unique()
act_values = np.zeros(160)
act_dict= dict(zip(act_keys, act_values))

# %%
#filters data to show only observations that represent an activity
activities=combined_data[combined_data['Activity Name'].isnull()==False]

#groups by contact ID and puts each activity into a list for each contact activity: output shown below
#this represents the "journey a caller will take through activities"
act_journey=activities.groupby('Contact Session ID').apply(lambda x: x['Activity Name'].tolist())

#same is done for flows
flows=combined_data[combined_data['Flow Name'].isnull()==False]
flow_journey = flows.groupby('Contact Session ID').apply(lambda x: x['Flow Name'].tolist())


act_journey.head()
# Out:
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/278942519.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   act_journey=activities.groupby('Contact Session ID').apply(lambda x: x['Activity Name'].tolist())
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/278942519.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   flow_journey = flows.groupby('Contact Session ID').apply(lambda x: x['Flow Name'].tolist())
# Contact Session ID
# 00002422-f51f-458b-82d6-cfa5a3f36fd9    [LanguageSelectionMenu, MainMenu, StaffDirecto...
# 00011655-35de-476f-9a8c-dd48ed4d914a    [LanguageSelectionMenu, LanguageSelectionMenu,...
# 00014a58-a6ce-4cb2-a529-d55e2c9c304d    [LanguageSelectionMenu, MainMenu, SeniorsMenu,...
# 00023e47-b722-4e2f-b2e2-855911d085fd                    [LanguageSelectionMenu, MainMenu]
# 0002f64b-59d3-4cba-885c-83b997d2fc73    [LanguageSelectionMenu, LanguageSelectionMenu,...
# dtype: object

# %%
def bar_graph(cat, y_label='Num Of Repeats'):
    plt.figure(figsize=(12, 8))
    ax=sns.barplot(cat, color='#f73c1b')
    for p in ax.patches:
        height = p.get_height()
        if not np.isnan(height) and height > 0:
            ax.text(
            p.get_x() + p.get_width() / 2,
            height,
            f'{height:.1f}',
            ha='center',
            va='bottom',
            fontsize=20  # 👈 Smaller font size for numbers
        )

    # Improve x-axis labels
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=14)
    ax.set_ylabel(y_label, fontsize=14)
    plt.tight_layout()
    plt.show()

# %%
#making shapes for each the same
act_journey.drop(index=list(set(act_journey.index)-set(flow_journey.index)), inplace=True)
flow_journey.drop(index=list(set(flow_journey.index)-set(act_journey.index)), inplace=True)

# %%
#if the only activity a caller goes to is language selection, their only flow should be LACMain, removes some instances of double counting
flow_journey[act_journey[act_journey.apply(lambda x: set(x)=={'LanguageSelectionMenu'})].index] = flow_journey[act_journey[act_journey.apply(lambda x: set(x)=={'LanguageSelectionMenu'})].index].apply(lambda x: ['LACMain'])

# %%
# adds main menu where it is recorded as LACMain
def fix_LACMain(x):
    if len(x)>1:
        if x[1] == 'LACMain':
            x[1] = 'MainMenu'
    return x

# %%
#same as above but for holiday (WILL BE CHANGING THIS AS LOGIC IS NOT ALWAYS CORRECT)
def fix_LACMain2(x):
    if len(x)>1:
        if x[1] == 'LACMain':
            x[1] = 'HolidayClosedMenu'
    return x

# %%
#applying above functions on elements that are necessary
flow_journey[act_journey[act_journey.apply(lambda x: 'MainMenu' in x)].index]=flow_journey[act_journey[act_journey.apply(lambda x: 'MainMenu' in x)].index].apply(lambda x: fix_LACMain(x))
flow_journey[act_journey[act_journey.apply(lambda x: 'MainMenu' not in x)].index]=flow_journey[act_journey[act_journey.apply(lambda x: 'MainMenu' not in x)].index].apply(lambda x: fix_LACMain2(x))

# %%
activity_counts=act_journey.apply(lambda x: Counter(x)) #creates a dictionary for each caller that gets the number of times a given activity
#appears in a journey, output shown below
flow_counts=flow_journey.apply(lambda x: Counter(x))

# %%
#creates an instance of the dictionary created above
num_repeated_flows=flow_dict.copy()

#iteraties through the series and adds the number-1 corresponding to each key to the dictionary that stores the total number of repeats
#we add the minus 1 so we count the number of repeats(if a caller goes through main menu twice, that should count as one repeat)
for x in flow_counts:
    for key in x.keys(): 
        num_repeated_flows[key]+=x[key]-1
#converts to series and sorts for the graph
num_repeated_flows=pd.Series(num_repeated_flows).sort_values(ascending=False)

#creates an other category to make the graph below look cleaner
condensed_num_repeated_flows = num_repeated_flows[num_repeated_flows>=1000]
condensed_num_repeated_flows=pd.concat([condensed_num_repeated_flows,pd.Series(num_repeated_flows[num_repeated_flows<1000].sum(),index=['Other'])])

# %%
bar_graph(condensed_num_repeated_flows)
# Out:
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/4207053395.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=14)

# %%
#all of this is the same as above but for activities
num_repeated_activities = act_dict.copy()
for x in activity_counts:
    for key in x.keys(): 
        num_repeated_activities[key]+=x[key]-1
num_repeated_activities=pd.Series(num_repeated_activities).sort_values(ascending=False)
condesed_num_repeated_activities = num_repeated_activities[num_repeated_activities>5000]
condesed_num_repeated_activities=pd.concat([condesed_num_repeated_activities,pd.Series(num_repeated_activities[num_repeated_activities<5000].sum(),index=['Other'])])

# %%
bar_graph(condesed_num_repeated_activities)
# Out:
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/4207053395.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=14)

# %%
#this function iterates through a list, and checks whether a value is a repeat and if so, records the value in front of it
#this seeks to find flows/activities that cause users to go back to things they have already been to
def find_repeat_cause_flows(l):

    #this stores the number of times each value appears in the list, used to identify repeats
    counter = flow_dict.copy()

    #this stores the number of times each value "causes" a repeat
    repeat_counter = flow_dict.copy()
    
    for i in range(len(l)):
        counter[l[i]]+=1
        if counter[l[i]]>1:
            repeat_counter[l[i-1]]+=1
    #gets rid of zeroes in the dictionary
    return {key: value for key, value in repeat_counter.items() if value != 0}

# %%
#above function applied on the series
repeat_flow_causes=flow_journey.apply(lambda x: find_repeat_cause_flows(x))

# %%
#aggregates the series to get a total count for each flow
total_flow_cause_count=flow_dict.copy()
for x in repeat_flow_causes:
    for key in x.keys(): 
        total_flow_cause_count[key]+=x[key]

#removes the dict entries that have a value of zero
total_flow_cause_count={key: value for key, value in total_flow_cause_count.items() if value != 0}

#sorts and converts to a series
total_flow_cause_count=pd.Series(total_flow_cause_count).sort_values(ascending=False)
condesed_num_cause_flows = total_flow_cause_count[total_flow_cause_count>400]
condesed_num_cause_flows=pd.concat([condesed_num_cause_flows,pd.Series(total_flow_cause_count[total_flow_cause_count<400].sum(),
                                                                                       index=['Other'])])

# %%
bar_graph(condesed_num_cause_flows)
# Out:
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/4207053395.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=14)

# %%
#exact same as above function but for activities
#everthing else below is the same
def find_repeat_cause_activities(l):
    counter = act_dict.copy()
    repeat_counter = act_dict.copy()
    for i in range(len(l)):
        counter[l[i]]+=1
        if counter[l[i]]>1:
            repeat_counter[l[i-1]]+=1
    return {key: value for key, value in repeat_counter.items() if value != 0}

# %%
repeat_act_causes=act_journey.apply(lambda x: find_repeat_cause_activities(x))

# %%
total_act_cause_count=act_dict.copy()
for x in repeat_act_causes:
    for key in x.keys(): 
        total_act_cause_count[key]+=x[key]
total_act_cause_count={key: value for key, value in total_act_cause_count.items() if value != 0}

# %%
total_act_cause_count=pd.Series(total_act_cause_count).sort_values(ascending=False)
total_act_cause_count.drop(['PlayMOH300s','QueueMenu1'], inplace=True)

condensed_total_act_cause_count = total_act_cause_count[total_act_cause_count>=2500]
condensed_total_act_cause_count=pd.concat([condensed_total_act_cause_count,pd.Series(total_act_cause_count[total_act_cause_count<2500].sum(),
                                                                                     index=['Other'])])

# %%
bar_graph(condensed_total_act_cause_count, 'Num of Causes')
# Out:
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/4207053395.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=14)

# %%
#this function iterates through a list and find the number of times each value appears back to back
def find_repeat_activities(l):
    #used to store number of b2b repeats
    counter = act_dict.copy()
    for i in range(1,len(l)):

        #checks if item is the same as the one before it
        if l[i]==l[i-1]:
            counter[l[i]]+=1

    #gets rid of zeroes
    return {key: value for key, value in counter.items() if value != 0}

# %%
#next steps until the graph are the same as before
activity_repeat_counts = act_journey.apply(lambda x: find_repeat_activities(x))

# %%
total_act_b2brepeat_count=act_dict.copy()
for x in activity_repeat_counts:
    for key in x.keys(): 
        total_act_b2brepeat_count[key]+=x[key]
total_act_b2brepeat_count={key: value for key, value in total_act_b2brepeat_count.items() if value != 0}
total_act_b2brepeat_count=pd.Series(total_act_b2brepeat_count).sort_values(ascending=False)

# %%
#now doing the same for flows, if data is recorded correctly, no flow should be repeated 
#so this is used to identify mistakes in the way the data is collected
def find_repeat_flows(l):
    counter = flow_dict.copy()
    for i in range(1,len(l)):
        if l[i]==l[i-1]:
            counter[l[i]]+=1
    return {key: value for key, value in counter.items() if value != 0}

# %%
flow_repeat_counts = flow_journey.apply(lambda x: find_repeat_flows(x))

# %% [markdown]
# ## Non-consec repeats

# %%
def find_between_repeats(col, activity=True, limit=0): #limit is for the minimum number of instances to not be classified as other
    if activity:
        journey=act_journey
        counts=activity_counts
    else:
        journey=flow_journey
        counts=flow_counts
    
    #filters the activity_counts series to only show calls that repeat a certain activity/flow
    repeated=counts.apply(lambda x: x[col]>=2) 
    
    #for the ones where senior repeat, this finds the indices in the journey where the caller goes to the seniors menu
    where_repeats=journey[repeated[repeated==True].index].apply(lambda x: [i for i, val in enumerate(x) if val==col])

    #filters for only non-consecutive repeats
    repeats_distanced=where_repeats[where_repeats.apply(lambda x: x[-1]-x[0]>len(x)-1)]

    #made dataframe with contact session IDs, their activity journey, and their difference from above, made a df for the next apply function to be easier
    df=pd.concat([journey[repeats_distanced.index],repeats_distanced], axis=1)
    df.rename(columns={0:'journey',1:'indices'}, inplace=True)
    
    #find the activities in the journey that fall between the first and last repeated activities

    if activity:
        between_repeats=df.apply(lambda x: Counter(x['journey'][x['indices'][0]+1:x['indices'][-1]]),axis=1)
        between_count=act_dict.copy()
        for x in between_repeats:
            for key in x.keys(): 
                between_count[key]+=x[key]
        between_count={key: value for key, value in between_count.items() if value != 0}
        between_count=pd.Series(between_count).sort_values(ascending=False)
    else:
        between_repeats=df.apply(lambda x: x['journey'][x['indices'][0]+1:x['indices'][-1]],axis=1)
        between_count=between_repeats.value_counts()

    #make graph readable
    condensed_between = between_count[between_count>=limit]
    condensed_between_count=pd.concat([condensed_between,pd.Series(between_count[between_count<limit].sum(),
                                                                                     index=['Other'])])
    if activity:  
        bar_graph(condensed_between_count, 'Num of Instances Between Repeats')
    print('Percent of callers who land on', col, 'that repeat:', round(between_repeats.shape[0]/journey[journey.apply(lambda x: col in x)].shape[0]*100,2),'%')
    print(between_repeats.shape[0])
    print(journey[journey.apply(lambda x: col in x)].shape[0])


    return between_repeats

# %%
find_between_repeats('MainMenu', True, 100)
# Out:
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/4207053395.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=14)
# Percent of callers who land on MainMenu that repeat: 4.99 %
# 5218
# 104664
# Contact Session ID
# 00011655-35de-476f-9a8c-dd48ed4d914a                {'HelpWithLegalorOtherReasonMenu': 1}
# 00129ffc-5b9d-492b-9844-5aa9e13b9035                           {'AddressFaxHoursMenu': 1}
# 0021ab55-6af9-48a5-ac17-b2a11ca7b438                {'HelpWithLegalorOtherReasonMenu': 1}
# 005446de-d319-445c-9855-185d2e706544    {'HelpWithLegalorOtherReasonMenu': 1, 'MainMen...
# 0056a873-dcbc-48a7-b9c6-4b42193f1bad            {'MainMenu': 1, 'AddressFaxHoursMenu': 1}
#                                                               ...
# ffb9e9e2-7cc9-482b-b2e8-bb0506e83cd3                {'HelpWithLegalorOtherReasonMenu': 1}
# ffbdabb1-59aa-4d39-bb5c-524117803a34                           {'AddressFaxHoursMenu': 1}
# ffd63901-44cc-46a5-975c-f8d71d39f4b2                {'HelpWithLegalorOtherReasonMenu': 1}
# fffa91b4-9401-4cb1-a956-e91c26185f34      {'ComplimentOrComplaintMenu': 2, 'MainMenu': 3}
# fffbb7f5-c87c-47cb-9509-7d11c2bc3764                               {'AppointmentMenu': 1}
# Length: 5218, dtype: object

# %%
find_between_repeats('LegalMenu2', True, 500)
# Out:
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/4207053395.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=14)
# Percent of callers who land on LegalMenu2 that repeat: 8.94 %
# 5145
# 57538
# Contact Session ID
# 00278c5c-3b80-4731-800c-3ac565ab2e18                                    {'FamilyMenu': 1}
# 0042b86b-acd1-435d-8498-0e46d33f62ca                                   {'HousingMenu': 1}
# 00473f4a-e9cf-4b87-9c9a-a14ac0c71fa3    {'OtherLegalMenu': 2, 'OtherLegalOtherMenu': 1...
# 0056a873-dcbc-48a7-b9c6-4b42193f1bad                                   {'HousingMenu': 1}
# 005c7447-5f2b-4e37-9404-4fb795654916    {'OtherLegalMenu': 5, 'OtherLegalOtherMenu': 2...
#                                                               ...
# ff918d72-3105-40ec-a0bc-3af3c6964619                                   {'HousingMenu': 1}
# ff951e3e-fddf-4efa-b93a-3fd0c7364d3b      {'OtherLegalMenu': 4, 'OtherLegalOtherMenu': 1}
# ffb69a7a-e7c1-4a2d-b6c3-eb9e8f98f690    {'HousingMenu': 3, 'LegalMenu2': 2, 'PreTenant...
# ffd63901-44cc-46a5-975c-f8d71d39f4b2                                    {'FamilyMenu': 1}
# ffe9ae44-a7ab-4418-8512-e3100b01f84b                                    {'FamilyMenu': 1}
# Length: 5145, dtype: object

# %%
find_between_repeats('SeniorsMenu', True, 50)
# Out:
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/4207053395.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=14)
# Percent of callers who land on SeniorsMenu that repeat: 0.24 %
# 164
# 67729
# Contact Session ID
# 018d6808-fc24-4489-890c-9e4cf7a06496    {'LegalMenu1': 1, 'LegalMenu2': 4, 'OtherLegal...
# 025d38f5-3f80-4cb7-bfa7-f121f0d6b005    {'SeniorsConfirmationMenu': 1, 'SuburbsOrCityM...
# 038daa30-0fd1-49cd-9a83-8a81ab59cebb    {'LegalMenu1': 1, 'LegalMenu2': 3, 'MainMenu': 1}
# 0410a2c7-b3ee-48df-b4cc-e0e8decd01c4    {'SeniorsConfirmationMenu': 1, 'SuburbsOrCityM...
# 04331b48-9365-4a14-9c51-00ba86c1bea4    {'LegalMenu1': 1, 'LegalMenu2': 3, 'MainMenu': 1}
#                                                               ...
# fd66ee74-2faf-49bb-8915-6b615e874cfa    {'SeniorsMenu': 1, 'SeniorsConfirmationMenu': ...
# fde43254-b448-49b1-8c22-0b4b1237c751    {'SeniorsConfirmationMenu': 1, 'SuburbsOrCityM...
# fed80952-0c86-42d2-b737-97fcedbfe860    {'SeniorsMenu': 1, 'LegalMenu1': 1, 'LegalMenu...
# fef71d6c-703a-457d-b136-670665688a64    {'LegalMenu1': 1, 'LegalMenu2': 8, 'OtherLegal...
# ff128b5b-4745-4b80-9e1a-47241ca45030    {'SeniorsConfirmationMenu': 1, 'SuburbsOrCityM...
# Length: 164, dtype: object

# %%
find_between_repeats('OtherLegalMenu', True, 100)
# Out:
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/4207053395.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=14)
# Percent of callers who land on OtherLegalMenu that repeat: 68.18 %
# 5914
# 8674
# Contact Session ID
# 000c4a17-31a4-4f9c-be31-7256e06b5f5e                           {'OtherLegalOtherMenu': 1}
# 002e5e73-c0c5-42f4-b04e-ee9babc7d88b                           {'OtherLegalOtherMenu': 1}
# 003373f1-7032-4b9e-b08d-c6a5275ee085      {'OtherLegalMenu': 1, 'OtherLegalOtherMenu': 1}
# 003cc587-2d97-495a-99c2-851e7794e144      {'OtherLegalOtherMenu': 1, 'OtherLegalMenu': 1}
# 00473f4a-e9cf-4b87-9c9a-a14ac0c71fa3                           {'OtherLegalOtherMenu': 1}
#                                                               ...
# ffa59a94-f3ff-45b6-bae8-ed2d68c76256                           {'OtherLegalOtherMenu': 1}
# ffa92377-85b9-4ad7-be0d-2a3cebd218a3      {'OtherLegalOtherMenu': 2, 'OtherLegalMenu': 1}
# ffacd63d-bec5-4a75-a1c0-5c9932be8d00                           {'OtherLegalOtherMenu': 1}
# ffc41240-311d-495a-be2b-441c60ae36c2    {'OtherLegalOtherMenu': 2, 'OtherLegalMenu': 3...
# ffe9ae44-a7ab-4418-8512-e3100b01f84b                           {'OtherLegalOtherMenu': 1}
# Length: 5914, dtype: object

# %%
find_between_repeats('LegalMenu1', True, 20)
# Out:
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/4207053395.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=14)
# Percent of callers who land on LegalMenu1 that repeat: 0.16 %
# 95
# 59730
# Contact Session ID
# 038daa30-0fd1-49cd-9a83-8a81ab59cebb    {'LegalMenu2': 3, 'MainMenu': 1, 'SeniorsMenu'...
# 04331b48-9365-4a14-9c51-00ba86c1bea4    {'LegalMenu2': 3, 'MainMenu': 1, 'SeniorsMenu'...
# 0b1f4d4c-82e7-4e40-b699-cf7f29b95ec0    {'LegalMenu2': 6, 'MainMenu': 2, 'SeniorsMenu'...
# 0b3ef0de-9fae-4b06-be15-e4ccce3b7f18    {'LegalMenu2': 3, 'MainMenu': 1, 'SeniorsMenu'...
# 0ce9a87e-5c3d-4efe-9dd9-200085685b20    {'LegalMenu2': 3, 'MainMenu': 1, 'HelpWithLega...
#                                                               ...
# fb8c3548-4475-4fd3-8702-ec649abb3782    {'LegalMenu2': 3, 'SeniorsMenu': 1, 'SeniorsCo...
# fbd2000a-a2f7-4555-94d3-f59c14a572a2    {'LegalMenu2': 3, 'MainMenu': 1, 'SeniorsMenu'...
# fde43254-b448-49b1-8c22-0b4b1237c751    {'LegalMenu2': 3, 'MainMenu': 2, 'AppointmentM...
# fed80952-0c86-42d2-b737-97fcedbfe860    {'LegalMenu2': 3, 'MainMenu': 1, 'AppointmentM...
# ff128b5b-4745-4b80-9e1a-47241ca45030    {'LegalMenu2': 3, 'MainMenu': 1, 'AppointmentM...
# Length: 95, dtype: object

# %%
find_between_repeats('LegalMenu', False).value_counts()
# Out:
# Percent of callers who land on LegalMenu that repeat: 8.46 %
# 5051
# 59687
# [LegalHousingMenu]                                                                                                                                                                                    1310
# [LegalFamilyMenu]                                                                                                                                                                                     1247
# [OtherLegalMenu]                                                                                                                                                                                      1095
# [LegalHIVMenu]                                                                                                                                                                                         236
# [LegalHousingMenu, LegalMenu, LegalHousingMenu]                                                                                                                                                        131
#                                                                                                                                                                                                       ...
# [LegalFamilyMenu, LegalMenu, LegalFamilyMenu, LegalMenu, LACMain, PreLegalMenuSeniorsMenu, LegalMenu, LACMain, PreLegalMenuSeniorsMenu, LegalMenu, LegalHousingMenu, LegalMenu, LegalBenefitsMenu]       1
# [LegalHousingMenu, LegalMenu, LegalHousingMenu, LegalMenu, LegalHousingMenu, LegalMenu, LACMain, PreLegalMenuSeniorsMenu]                                                                                1
# [LegalImmigrationMenu, LegalMenu, LegalFamilyMenu]                                                                                                                                                       1
# [OtherLegalMenu, LegalMenu, LegalHousingMenu, LegalMenu, LegalHousingMenu, LegalMenu, LegalHousingMenu, LegalMenu, LegalHousingMenu]                                                                     1
# [OtherLegalMenu, LegalMenu, OtherLegalMenu, LegalMenu, OtherLegalMenu, LegalMenu, LegalHousingMenu]                                                                                                      1
# Name: count, Length: 166, dtype: int64

# %%
find_between_repeats('HousingMenu', True)
# Out:
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/4207053395.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=14)
# Percent of callers who land on HousingMenu that repeat: 16.25 %
# 1851
# 11392
# Contact Session ID
# 0033dc08-7287-420e-9344-181ac2edcdb1                {'PreTenantMenu': 1, 'TenantMenu': 1}
# 007ea584-df7a-45a8-b878-eaf5235928de    {'PreTenantMenu': 1, 'TenantMenu': 3, 'TenantD...
# 00930395-924a-4bdb-ad4e-b2b6391a60c4                                    {'LegalMenu2': 1}
# 00db2f64-a31a-4615-bcff-669b320e20bb    {'PreTenantMenu': 1, 'TenantMenu': 2, 'TenantD...
# 00dca7b5-4fc3-4b62-844e-ae5ba836161e                                    {'LegalMenu2': 1}
#                                                               ...
# ff9d696a-0ec6-4164-bd57-13f7bb280510                {'PreTenantMenu': 1, 'TenantMenu': 1}
# ffa0279e-ef3b-4ae5-bdf3-e0e8e4a43569    {'PreTenantMenu': 1, 'TenantMenu': 2, 'TenantD...
# ffb69a7a-e7c1-4a2d-b6c3-eb9e8f98f690    {'LegalMenu2': 2, 'HousingMenu': 1, 'PreTenant...
# ffc3e76f-c91e-406d-b379-676a94cc73e9    {'PreTenantMenu': 2, 'TenantMenu': 2, 'Housing...
# fff76b53-9816-46bc-b633-86015f00a972    {'PreTenantMenu': 1, 'TenantMenu': 2, 'TenantD...
# Length: 1851, dtype: object

# %%
flow_journey[flow_journey.apply(lambda x: 'LegalHIVMenu' in x)]
# Out:
# Contact Session ID
# 0035b5f4-1e5f-4359-b982-ddbf7df6f1dd    [LACMain, MainMenu, PreLegalMenuSeniorsMenu, L...
# 00916f73-d11b-4cd9-9518-a2fba107b1a7    [LACMain, MainMenu, PreLegalMenuSeniorsMenu, L...
# 00b6ba57-88c3-4d38-8dd8-b11bb7fc8e34    [LACMain, MainMenu, PreLegalMenuSeniorsMenu, L...
# 0102c235-461a-44e0-8c54-0c4ac0d17ad1    [LACMain, PreLegalMenuSeniorsMenu, PreLegalMen...
# 015f0322-6f5e-4d75-a6e4-be21a6fcdb01    [LACMain, MainMenu, PreLegalMenuSeniorsMenu, L...
#                                                               ...
# febb4b00-d616-4970-a5b8-19bb5ba93d14    [LACMain, PreLegalMenuSeniorsMenu, PreLegalMen...
# fed6bfa2-6923-4b7b-9dbc-42be043a8e75    [LACMain, MainMenu, PreLegalMenuSeniorsMenu, L...
# ff176f75-fa0f-4119-b2b9-d7ae48f0f308    [LACMain, MainMenu, PreLegalMenuSeniorsMenu, L...
# ff280542-ba88-415f-b808-c9545121de80    [LACMain, MainMenu, PreLegalMenuSeniorsMenu, L...
# ff760842-55ab-4702-a89f-6448b79d468d    [LACMain, MainMenu, PreLegalMenuSeniorsMenu, L...
# Length: 1349, dtype: object

# %%
find_between_repeats('PreLegalMenuSeniorsMenu', False)
# Out:
# Percent of callers who land on PreLegalMenuSeniorsMenu that repeat: 0.24 %
# 164
# 67729
# Contact Session ID
# 018d6808-fc24-4489-890c-9e4cf7a06496      [LegalMenu, OtherLegalMenu, LegalMenu, LACMain]
# 025d38f5-3f80-4cb7-bfa7-f121f0d6b005                                 [LegalMenu, LACMain]
# 038daa30-0fd1-49cd-9a83-8a81ab59cebb                                 [LegalMenu, LACMain]
# 0410a2c7-b3ee-48df-b4cc-e0e8decd01c4    [LegalMenu, OtherLegalMenu, LegalMenu, LACMain...
# 04331b48-9365-4a14-9c51-00ba86c1bea4                                 [LegalMenu, LACMain]
#                                                               ...
# fd66ee74-2faf-49bb-8915-6b615e874cfa    [LegalMenu, LegalHousingMenu, LegalMenu, LACMain]
# fde43254-b448-49b1-8c22-0b4b1237c751                                 [LegalMenu, LACMain]
# fed80952-0c86-42d2-b737-97fcedbfe860                                 [LegalMenu, LACMain]
# fef71d6c-703a-457d-b136-670665688a64    [LegalMenu, OtherLegalMenu, LegalMenu, LACMain...
# ff128b5b-4745-4b80-9e1a-47241ca45030                                 [LegalMenu, LACMain]
# Length: 164, dtype: object

# %%
def has_non_consecutive_duplicate(lst, skip_values=None):
    if skip_values is None:
        skip_values = set()
    else:
        skip_values = set(skip_values)

    seen = {}
    for i, val in enumerate(lst):
        if val in skip_values:
            continue  
        if val in seen:
            if i - seen[val] > 1:
                return True
        seen[val] = i
    return False

# %%
non_consec_acts = act_journey.apply(has_non_consecutive_duplicate,skip_values=['PlayMOH300s','QueueMenu1'])
non_consec_flows = flow_journey.apply(has_non_consecutive_duplicate)
non_consec=pd.concat([non_consec_acts, non_consec_flows], axis=1).rename(columns={0:'activity', 1:'flow'})
non_consec[(non_consec.activity ==True) | (non_consec.flow==True)].shape[0]/act_journey.shape[0]
# Out:
# 0.13300711743772242

# %%
#filter for only seniors
seniors=act_journey[act_journey.apply(lambda x: 'SuburbsOrCityMenu' in x)]

# %%
from collections import defaultdict

def count_non_consecutive_repeats(lst):
    positions = defaultdict(list)
    
    for i, val in enumerate(lst):
        positions[val].append(i)
    
    result = {}
    for val, idxs in positions.items():
        # Check if there are at least two indices
        if len(idxs) > 1:
            # Check for at least one non-consecutive repeat
            non_consec = any(abs(a - b) > 1 for a, b in zip(idxs, idxs[1:]))
            if non_consec:
                result[val] = sum(abs(a - b) > 1 for a, b in zip(idxs, idxs[1:]))
    
    return result

# %%
non_consec_repeats_all_activities = act_journey.apply(count_non_consecutive_repeats)
non_consec_act_count = act_dict.copy()
for x in non_consec_repeats_all_activities:
    for key in x.keys(): 
        non_consec_act_count[key]+=1
non_consec_act_count = {key: value for key, value in non_consec_act_count.items() if value != 0}
non_consec_act_count=pd.Series(non_consec_act_count).sort_values(ascending=False)
non_consec_act_count.drop(['PlayMOH300s','QueueMenu1'], inplace=True)
condensed_non_consec_act_count = non_consec_act_count[non_consec_act_count>=1000]
condensed_non_consec_act_count=pd.concat([condensed_non_consec_act_count,pd.Series(non_consec_act_count[non_consec_act_count<1000].sum(),
                                                                                     index=['Other'])])
bar_graph(condensed_non_consec_act_count, 'Num Of Callers Who Repeat')
# Out:
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/4207053395.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=14)

# %%
non_consec_repeats_all_flows = flow_journey.apply(count_non_consecutive_repeats)
non_consec_flow_count = flow_dict.copy()
for x in non_consec_repeats_all_flows:
    for key in x.keys(): 
        non_consec_flow_count[key]+=1
non_consec_flow_count = {key: value for key, value in non_consec_flow_count.items() if value != 0}
non_consec_flow_count=pd.Series(non_consec_flow_count).sort_values(ascending=False)
condensed_non_consec_flow_count = non_consec_flow_count[non_consec_flow_count>=200]
condensed_non_consec_flow_count=pd.concat([condensed_non_consec_flow_count,pd.Series(non_consec_flow_count[non_consec_flow_count<150].sum(),
                                                                                     index=['Other'])])
bar_graph(condensed_non_consec_flow_count, 'Num of Callers Who Repeat')
# Out:
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/4207053395.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=14)

# %%
flow_journey[flow_journey.apply(lambda x: 'LACMain' in x[1:])].value_counts()
# Out:
# [LACMain, MainMenu, LACMain]                                                                                                                                                                                                                                                                                      785
# [LACMain, MainMenu, PreLegalMenuSeniorsMenu, LegalMenu, LACMain]                                                                                                                                                                                                                                                   53
# [LACMain, MainMenu, PreLegalMenuSeniorsMenu, LegalMenu, LACMain, PreLegalMenuSeniorsMenu, LegalMenu]                                                                                                                                                                                                               19
# [LACMain, MainMenu, PreLegalMenuSeniorsMenu, LegalMenu, OtherLegalMenu, LegalMenu, LACMain]                                                                                                                                                                                                                        13
# [LACMain, MainMenu, PreLegalMenuSeniorsMenu, LegalMenu, LegalHousingMenu, LegalMenu, LACMain]                                                                                                                                                                                                                      11
#                                                                                                                                                                                                                                                                                                                  ...
# [LACMain, MainMenu, PreLegalMenuSeniorsMenu, LegalMenu, LACMain, PreLegalMenuSeniorsMenu, LegalMenu, LegalFamilyMenu, Queues, CourtesyCallback]                                                                                                                                                                     1
# [LACMain, MainMenu, PreLegalMenuSeniorsMenu, LegalMenu, OtherLegalMenu, LegalMenu, LACMain, PreLegalMenuSeniorsMenu, LegalMenu, LegalEmploymentMenu, Queues, ClosedQueueMenu]                                                                                                                                       1
# [LACMain, MainMenu, PreLegalMenuSeniorsMenu, LegalMenu, LegalFamilyMenu, LegalMenu, LegalFamilyMenu, LegalMenu, LACMain, PreLegalMenuSeniorsMenu, LegalMenu, LACMain, PreLegalMenuSeniorsMenu, LegalMenu, LegalHousingMenu, LegalMenu, LegalBenefitsMenu, LegalMenu, Queues, ClosedQueueMenu, ClosedQueueMenu]      1
# [LACMain, MainMenu, PreLegalMenuSeniorsMenu, LegalMenu, LegalHousingMenu, LegalMenu, LegalHousingMenu, LegalMenu, LegalHousingMenu, LegalMenu, LACMain, PreLegalMenuSeniorsMenu, LegalMenu, LegalHousingMenu]                                                                                                       1
# [LACMain, MainMenu, PreLegalMenuSeniorsMenu, LegalMenu, OtherLegalMenu, LegalMenu, LACMain, PreLegalMenuSeniorsMenu, LegalMenu, LegalFamilyMenu, LegalMenu, LACMain, PreLegalMenuSeniorsMenu, LegalMenu, OtherLegalMenu]                                                                                            1
# Name: count, Length: 105, dtype: int64

# %% [markdown]
# ## Menu Resdesign

# %%
#filters only callers than reach the prelegal seniors menu, my determination for if they have a legal issue
legal_issue=act_journey[act_journey.apply(lambda x: 'SeniorsMenu' in x)]

# %%
#this is a list that stores all the activity endpoints that are not queues

canthelp_list=['ClinicVoicemailTransfer','SimpleDivorceMenu', 'ChildSupportMenu','WorkersCompMenu','ImmigrationOtherMenu',
            'OtherLegalCriminalCaseMenu', 'OtherLegalPersonalInjuryMenu','OtherLegalOtherMenu','SeniorNotCookCoMenu','OtherLegalMenu',
            'FrontDeskTransfer','TenantDeterrenceMenu','ThankYouGoodbye','OtherLegalMenu', 'HIVVoicemailTransfer',
               'VeteransBenefitsVoicemailTransfer', 'TraffickingVoicemailTransfer', 'CriminalRecordsVoicemailTransfer']

# %%
#converts the start time column to datetime
activities['timestamps'] = pd.to_datetime(activities['Activity Start Timestamp'], format="%Y/%m/%d %I:%M:%S %p")
# Out:
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/4002517309.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   activities['timestamps'] = pd.to_datetime(activities['Activity Start Timestamp'], format="%Y/%m/%d %I:%M:%S %p")

# %%
#filters to only show seniorsmenu and legal meny or city in order to find median time diff between them for seniors
seniors_menu_time=activities[activities['Activity Name'].apply(lambda x: x in ['SeniorsMenu','LegalMenu1'])]

#filters for only callers that are senior but not suburban
city_seniors=act_journey[act_journey.apply(lambda x: 'SuburbsOrCityMenu' in x and 'SuburbanSeniorsMenu' not in x and 'LegalMenu1' in x)]

#filters the entire dataset to show only city seniors
city_seniors_all=seniors_menu_time[seniors_menu_time['Contact Session ID'].apply(lambda x: x in city_seniors.index)]

#finds the difference in time between the two activities
diffs=city_seniors_all.groupby('Contact Session ID').apply(lambda x: x.iloc[[0,-1],-1].diff())

#median
diffs[diffs.dt.seconds>0].dt.seconds.median()
# Out:
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/701709518.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   diffs=city_seniors_all.groupby('Contact Session ID').apply(lambda x: x.iloc[[0,-1],-1].diff())
# 69.0

# %%
#filters for only callers that are non-seniors 
non_seniors=act_journey[act_journey.apply(lambda x: 'SeniorsMenu' in x and 'SuburbsOrCityMenu' not in x and 'LegalMenu1' in x)]

#filters the entire dataset to show only city seniors
non_seniors_all=seniors_menu_time[seniors_menu_time['Contact Session ID'].apply(lambda x: x in non_seniors.index)]

#finds the difference in time between the two activities
diffs2=non_seniors_all.groupby('Contact Session ID').apply(lambda x: x.iloc[[0,-1],-1].diff())

#median
diffs2[diffs2.dt.seconds>0].dt.seconds.median()
# Out:
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/1131589939.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   diffs2=non_seniors_all.groupby('Contact Session ID').apply(lambda x: x.iloc[[0,-1],-1].diff())
# 9.0

# %%
#now finding the time reduction by removing the confirmation
#filters to only show seniorsmenu and legal meny or city in order to find median time diff between them for seniors
seniors_confirmation_time=activities[activities['Activity Name'].apply(lambda x: x in ['SeniorsConfirmationMenu','SuburbsOrCityMenu'])]

#filters the entire dataset to show only seniors
seniors_all=seniors_confirmation_time[seniors_confirmation_time['Contact Session ID'].apply(lambda x: x in seniors.index)]

#finds the difference in time between the two activities
diffs3=seniors_all.groupby('Contact Session ID').apply(lambda x: x.iloc[[0,-1],-1].diff())

#median
diffs3[diffs3.dt.seconds>0].dt.seconds.median()
# Out:
# /var/folders/f_/gq8170f507s6psphh_d6670w0000gn/T/ipykernel_85953/1861617729.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   diffs3=seniors_all.groupby('Contact Session ID').apply(lambda x: x.iloc[[0,-1],-1].diff())
# 16.0

# %%
#number of suburban seniors - 16 seconds affected
legal_issue[legal_issue.apply(lambda x: 'SuburbanSeniorsMenu' in x)].shape[0]
# Out:
# 5099

# %%
#number of seniors who did not go to a queue - 69 seconds affected
legal_issue[legal_issue.apply(lambda x: x[-1] in canthelp_list and 'ClosedQueueMenu' not in x and 'SuburbsOrCityMenu' in x )].shape[0]
# Out:
# 2952

# %%
#number of non seniors who did not go to a queue - 9 seconds affected
legal_issue[legal_issue.apply(lambda x: x[-1] in canthelp_list and 'ClosedQueueMenu' not in x and 'SuburbsOrCityMenu' not in x)].shape[0]
# Out:
# 10412

# %%
#number of non seniors who went to a queue - 16 seconds affected
legal_issue[legal_issue.apply(lambda x: ((x[-1] not in canthelp_list or 'ClosedQueueMenu' in x)
                              and 'SuburbanSeniorsMenu' not in x and 'SuburbsOrCityMenu' in x))].shape[0]
# Out:
# 9773

# %%
#number of legal issue callers unaffected
legal_issue.shape[0]-5099-2952-10412-9773
# Out:
# 39493

# %%
#finding number of callers affected
alex=pd.read_csv('callers_impacted_2.csv')
aj=pd.read_csv('legal_menu_goers.csv')

# %%
daniel=set(legal_issue[legal_issue.apply(lambda x: 'SuburbsOrCityMenu' in x or (x[-1] in canthelp_list and 'ClosedQueueMenu' not in x))].index)

# %%
ad=set(alex['Contact Session ID']).union(daniel)

# %%
len(set(aj['Contact Session ID']).union(ad))
# Out:
# 66169
